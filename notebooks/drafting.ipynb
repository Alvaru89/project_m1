# %%
import sqlite3
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
#Importing DATA
conn = sqlite3.connect('data/raw_data_project_m1.db')

sql_statement='''
          SELECT personal_info.uuid,country_info.country_code, career_info.normalized_job_code, personal_info.age
          FROM personal_info
          JOIN career_info ON personal_info.uuid=career_info.uuid
          JOIN country_info ON personal_info.uuid=country_info.uuid
          JOIN poll_info ON personal_info.uuid=poll_info.uuid
          '''
raw_df=pd.DataFrame(pd.read_sql_query(sql_statement, conn))

raw_df.head()
# raw_df.info()

# %%
#Cleaning age

#Exploring values
# age_values=raw_df['age'].unique()
# print(list(age_values))

# cleaning
clean_age=[]
for item in raw_df['age']:
    if "years old" in item:
        clean_age.append(int(item[0:2]))
    elif len(item)>=4:
        clean_age.append(2016-int(item))

raw_df['age']=clean_age #add to dataframe

raw_df['age']=raw_df['age']+4 #convert to 2020

# %%
#cleaning age with lambda function

def clean_age(item):
    if "years old" in item:
        return int(item[0:2])
    elif len(item) == 4:
        return 2016 - int(item)

raw_df["age"] = raw_df.apply(lambda x: clean_age(x["age"]), axis=1)

    
raw_df.head()

# %%
#Cleaning country_code

#Exploring values
# list(raw_df['country_code'].unique())
#Importing csv of country-country code
country_equiv=pd.read_csv('data/country_code.csv',names=['Country','Code'])

country_equiv['Country','Code'].to_dict()
#Converting to dictionary
country_dict={}
for i in country_equiv.index:
    k=country_equiv.loc[i,'Code']
    v=country_equiv.loc[i,'Country']
    country_dict[k[1:3]]=v
#Adding missing values
country_dict['GB']='Great Britain'
country_dict['GR']='Greece'
#Adding country to dataframe
for i in raw_df.index:
    code=raw_df.loc[i,'country_code']
    raw_df.loc[i,'country']=country_dict['code']

# %%
url = 'http://api.dataatwork.org/v1/jobs/'
job_dict={}
search_val=list(raw_df['normalized_job_code'].unique())
import requests 

for val in search_val:
    if val==None:
        job_dict[val]=None
    else:
        data=val
        res = requests.get(url+data)
        job_title= res.json()
        job_dict[val]=job_title['title']
# job_dict
print('Finished!')

# %%
job_dict2={}
with open('data/job_dict.csv', 'r') as t:
    reader=csv.reader(t)
    job_dict2={row[0]:row[1] for row in reader}

# %%
import csv
with open('data/job_dict.csv', 'w') as f:
    w = csv.writer(f)
    w.writerows(job_dict.items())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6ca321f76181> in <module>
#       2 with open('data/job_dict.csv', 'w') as f:
#       3     w = csv.writer(f)
# ----> 4     w.writerows(job_dict.items())
#       5
#
# NameError: name 'job_dict' is not defined

# %%
for i in raw_df.index:
    raw_df.loc[i,'Job Title']= job_dict[raw_df.loc[i,'normalized_job_code']]

# %%
raw_df.info()
raw_df['Job Title'].

# %%
job_counts=dict(raw_df['Job Title'].value_counts())
people_with_job=raw_df['Job Title'].count()


for i in raw_df.index:
    if pd.notnull(raw_df.loc[i,'Job Title']):
        raw_df.loc[i,'Quantity']= job_counts[raw_df.loc[i,'Job Title']]
        raw_df.loc[i,'Percentage']= job_counts[raw_df.loc[i,'Job Title']]*100/people_with_job

# %%
raw_df.head()

# %% [markdown]
# PREPARING FOR BONUS

# %%
import sqlite3
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
conn = sqlite3.connect('data/raw_data_project_m1.db')

sql_statement='''
        SELECT personal_info.uuid,country_info.country_code, career_info.normalized_job_code, 
        personal_info.age, career_info.dem_education_level, 
        poll_info.question_bbi_2016wave4_basicincome_argumentsfor, 
        poll_info.question_bbi_2016wave4_basicincome_argumentsagainst, 
        poll_info.question_bbi_2016wave4_basicincome_vote
              
          FROM personal_info
          JOIN career_info ON personal_info.uuid=career_info.uuid
          JOIN country_info ON personal_info.uuid=country_info.uuid
          JOIN poll_info ON personal_info.uuid=poll_info.uuid
          '''
bonus_df=pd.DataFrame(pd.read_sql_query(sql_statement, conn))
bonus_df.head(10)
# Out:
#                                    uuid country_code  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82           AT
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82           AT
# 2  83127080-da3d-0133-c74f-0a81e8b09a82           AT
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82           AT
# 4  24954a70-db98-0133-4a64-0a81e8b09a82           AT
# 5  28583060-dbe2-0133-ff9c-0a81e8b09a82           AT
# 6  b50dbb80-da53-0133-8956-0a81e8b09a82           AT
# 7  dd743bb0-d9a5-0133-53b2-0a81e8b09a82           AT
# 8  4fde2370-da48-0133-3a42-0a81e8b09a82           AT
# 9  9949c4c0-da5f-0133-c832-0a81e8b09a82           AT
#
#                 normalized_job_code           age dem_education_level  \
# 0                              None  61 years old                  no
# 1  861a9b9151e11362eb3c77ca914172d0  57 years old                high
# 2                              None  32 years old                None
# 3  049a3f3a2b5f85cb2971ba77ad66e10c  45 years old                high
# 4  f4b2fb1aa40f661488e2782b6d57ad2f  41 years old                high
# 5  27af8700f5577cec835acee2cb90a2ff          1990                high
# 6                              None          1990              medium
# 7  c1b670eba9ccb65e7c99f7da116d5b9c  47 years old              medium
# 8  d71c4164c99a5f9bca773e755a72f40f  34 years old              medium
# 9                              None          1994                  no
#
#      question_bbi_2016wave4_basicincome_argumentsfor  \
# 0                                  None of the above
# 1  It increases appreciation for household work a...
# 2            It creates more equality of opportunity
# 3     It reduces anxiety about financing basic needs
# 4     It reduces anxiety about financing basic needs
# 5  It encourages financial independence and self-...
# 6     It reduces anxiety about financing basic needs
# 7  It increases appreciation for household work a...
# 8  It creates more equality of opportunity | It r...
# 9  It increases solidarity, because it is funded ...
#
#   question_bbi_2016wave4_basicincome_argumentsagainst  \
# 0                                  None of the above
# 1          It might encourage people to stop working
# 2  Foreigners might come to my country and take a...
# 3                                  None of the above
# 4  It is impossible to finance | It might encoura...
# 5  It is impossible to finance | It might encoura...
# 6  Foreigners might come to my country and take a...
# 7  It might encourage people to stop working | Fo...
# 8  Foreigners might come to my country and take a...
# 9  Foreigners might come to my country and take a...
#
#   question_bbi_2016wave4_basicincome_vote
# 0                        I would not vote
# 1            I would probably vote for it
# 2                        I would not vote
# 3            I would probably vote for it
# 4            I would probably vote for it
# 5                 I would vote against it
# 6            I would probably vote for it
# 7            I would probably vote for it
# 8            I would probably vote for it
# 9                     I would vote for it

# %%
# Extracting job_title + job_skills
url = 'http://api.dataatwork.org/v1/jobs/'
job_dict={}
job_skills={}
search_val=bonus_df['normalized_job_code'].unique()
import requests 

for val in tqdm(search_val):
    if val==None:
        job_dict[val]=None
        job_skills[val]=None
    else:
        try:
            res = requests.get(url+val+'/related_skills')
            job_title=res.json()['job_title']
            job_dict[val] = job_title
            job_skills[val]={res.json()['skills'][i]['skill_name']:res.json()['skills'][i]['importance'] for i in range(len(res.json()['skills']))}
        except:
            res = requests.get(url+val)
            job_title=res.json()['title']
            job_dict[val] = job_title
            job_skills[val]=None
            
# job_skills
# Out:
# 100%|██████████| 157/157 [02:25<00:00,  1.08it/s]

# %%
trial=pd.DataFrame(job_skills).

bonus_df=bonus_df.merge(trial, how='left',left_on='normalized_job_code',right_index=True)

bonus_df
# Out:
#                                       uuid country_code  \
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82           AT
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82           AT
# 2     83127080-da3d-0133-c74f-0a81e8b09a82           AT
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82           AT
# 4     24954a70-db98-0133-4a64-0a81e8b09a82           AT
# ...                                    ...          ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82           SK
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82           SK
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82           SK
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82           SK
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82           SK
#
#                    normalized_job_code           age dem_education_level  \
# 0                                 None  61 years old                  no
# 1     861a9b9151e11362eb3c77ca914172d0  57 years old                high
# 2                                 None  32 years old                None
# 3     049a3f3a2b5f85cb2971ba77ad66e10c  45 years old                high
# 4     f4b2fb1aa40f661488e2782b6d57ad2f  41 years old                high
# ...                                ...           ...                 ...
# 9644  847165cfda6b1dc82ae22b967da8af2f  37 years old                high
# 9645  a4d5b8b38f9513825d0d94a981ebe962  53 years old                high
# 9646                              None          1992                 low
# 9647  775190277a849cba701b306a7b374c0a  47 years old                 low
# 9648  8a7a3f1bce0958ae9f090683e5a925b7  51 years old                high
#
#         question_bbi_2016wave4_basicincome_argumentsfor  \
# 0                                     None of the above
# 1     It increases appreciation for household work a...
# 2               It creates more equality of opportunity
# 3        It reduces anxiety about financing basic needs
# 4        It reduces anxiety about financing basic needs
# ...                                                 ...
# 9644  It reduces bureaucracy and administrative expe...
# 9645  It reduces bureaucracy and administrative expe...
# 9646     It reduces anxiety about financing basic needs
# 9647  It reduces bureaucracy and administrative expe...
# 9648  It reduces bureaucracy and administrative expe...
#
#      question_bbi_2016wave4_basicincome_argumentsagainst  \
# 0                                     None of the above
# 1             It might encourage people to stop working
# 2     Foreigners might come to my country and take a...
# 3                                     None of the above
# 4     It is impossible to finance | It might encoura...
# ...                                                 ...
# 9644                        It is impossible to finance
# 9645  It might encourage people to stop working | On...
# 9646                                  None of the above
# 9647  Foreigners might come to my country and take a...
# 9648  It might encourage people to stop working | It...
#
#      question_bbi_2016wave4_basicincome_vote computers and electronics  \
# 0                           I would not vote                      None
# 1               I would probably vote for it                      4.61
# 2                           I would not vote                      None
# 3               I would probably vote for it                      3.45
# 4               I would probably vote for it                       4.3
# ...                                      ...                       ...
# 9644            I would probably vote for it                      None
# 9645        I would probably vote against it                       4.3
# 9646                        I would not vote                      None
# 9647                     I would vote for it                      4.62
# 9648                 I would vote against it                       4.6
#
#      english language  ... dynamic strength stamina extent flexibility  \
# 0                None  ...             None    None               None
# 1                4.01  ...                1       1                  1
# 2                None  ...             None    None               None
# 3                3.55  ...                1       1                  1
# 4                3.21  ...                1       1               1.12
# ...               ...  ...              ...     ...                ...
# 9644             None  ...             None    None               None
# 9645             3.21  ...                1       1               1.12
# 9646             None  ...             None    None               None
# 9647             3.96  ...             1.88       1                  1
# ...                                            ...               ...
# b0fa6ede410f50b82ab74f5a705fe699                 1                 1
# 559a21f836c93876f31b60e6d10656a7                 1                 1
# c1fb1a01b78373ac2153c66fa08d16dc                 1                 1
# 05bb9a333a66d6eb151e253623efe1c0                 1                 1
# 4cee16550636e292b8d136486fce943b                 1                 1
#
#                                  food production
# NaN                                         None
# 861a9b9151e11362eb3c77ca914172d0               1
# 049a3f3a2b5f85cb2971ba77ad66e10c               1
# f4b2fb1aa40f661488e2782b6d57ad2f            1.06
# 27af8700f5577cec835acee2cb90a2ff               1
# ...                                          ...
# b0fa6ede410f50b82ab74f5a705fe699            1.17
# 559a21f836c93876f31b60e6d10656a7            1.85
# c1fb1a01b78373ac2153c66fa08d16dc               1
# 05bb9a333a66d6eb151e253623efe1c0               1
# 4cee16550636e292b8d136486fce943b               1
#
# [157 rows x 119 columns]

# %%
url = 'http://api.dataatwork.org/v1/jobs/'
job_dict={}
job_skills={}
search_val=list(bonus_df['normalized_job_code'].unique())
import requests 

data='19e384e977796c25780d8c28b12089c4' #error 404
data1='f4b2fb1aa40f661488e2782b6d57ad2f' #example
res = requests.get(url+data1+'/related_skills')
# res.json()

# job_title=res.json()['job_title']
# job_dict[val] = job_title
# job_skills[job_title]=[res.json()['skills'][i]['skill_name'] for i in range(len(res.json()['skills']))]

# job_skills
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-516ef064d6d3> in <module>
#       2 job_dict={}
#       3 job_skills={}
# ----> 4 search_val=list(bonus_df['normalized_job_code'].unique())
#       5 import requests
#       6
#
# NameError: name 'bonus_df' is not defined

# %%
with open('data/job_skills.csv', 'w') as f:
    w = csv.writer(f)
    w.writerows(job_skills.items())

# %%
bonus_df['Job Skills'] = bonus_df.apply(lambda x: job_skills[x['normalized_job_code']],axis=1)

bonus_df.head()
# Out:
#                                    uuid country_code  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82           AT
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82           AT
# 2  83127080-da3d-0133-c74f-0a81e8b09a82           AT
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82           AT
# 4  24954a70-db98-0133-4a64-0a81e8b09a82           AT
#
#                 normalized_job_code           age dem_education_level  \
# 0                              None  61 years old                  no
# 1  861a9b9151e11362eb3c77ca914172d0  57 years old                high
# 2                              None  32 years old                None
# 3  049a3f3a2b5f85cb2971ba77ad66e10c  45 years old                high
# 4  f4b2fb1aa40f661488e2782b6d57ad2f  41 years old                high
#
#      question_bbi_2016wave4_basicincome_argumentsfor  \
# 0                                  None of the above
# 1  It increases appreciation for household work a...
# 2            It creates more equality of opportunity
# 3     It reduces anxiety about financing basic needs
# 4     It reduces anxiety about financing basic needs
#
#   question_bbi_2016wave4_basicincome_argumentsagainst  \
# 0                                  None of the above
# 1          It might encourage people to stop working
# 2  Foreigners might come to my country and take a...
# 3                                  None of the above
# 4  It is impossible to finance | It might encoura...
#
#   question_bbi_2016wave4_basicincome_vote  \
# 0                        I would not vote
# 1            I would probably vote for it
# 2                        I would not vote
# 3            I would probably vote for it
# 4            I would probably vote for it
#
#                                           Job Skills
# 0                                               None
# 1  {'computers and electronics': 4.61, 'english l...
# 2                                               None
# 3  {'information ordering': 4.12, 'problem sensit...
# 4  {'computers and electronics': 4.3, 'problem se...

# %%
bonus_df.dropna(axis=0,subset=['dem_education_level','Job Skills'], inplace=True)

# %%
skill_list=[]
for list in tqdm(bonus_df['Job Skills']):
    if list!=None:
        for skill in list:
            if skill not in skill_list:
                skill_list.append(skill)
# Out:
# 100%|██████████| 4883/4883 [00:00<00:00, 9478.99it/s]

# %%
bonus_df=pd.concat([bonus_df,pd.DataFrame(columns=skill_list, dtype=float)])

# %%
for i in tqdm(bonus_df.index):
    if bonus_df.loc[i,'Job Skills']!=None:
        for skill,importance in bonus_df.loc[i,'Job Skills'].items():
            bonus_df.loc[i,skill]=float(importance)
# Out:
# 100%|██████████| 4883/4883 [02:11<00:00, 37.06it/s]

# %%
bonus_df.tail()

# %%
bonus_df.columns
bonus_df.drop(['uuid', 'country_code', 'normalized_job_code', 'age','Job Skills',
       'question_bbi_2016wave4_basicincome_argumentsfor',
       'question_bbi_2016wave4_basicincome_argumentsagainst',
       'question_bbi_2016wave4_basicincome_vote'], axis=1, inplace=True)

# %%
bonus_df.describe()
# Out:
#        computers and electronics  english language  critical thinking  \
# count                4883.000000       4883.000000        4883.000000
# mean                    4.304311          3.631503           3.687602
# std                     0.449819          0.339238           0.239209
# min                     2.240000          2.320000           2.880000
# 25%                     4.300000          3.210000           3.500000
# 50%                     4.300000          3.680000           3.750000
# 75%                     4.620000          3.960000           3.880000
# max                     4.880000          4.800000           4.120000
#
#        oral comprehension  problem sensitivity  information ordering  \
# count         4883.000000          4883.000000           4883.000000
# mean             3.736283             3.748177              3.652417
# std              0.214678             0.210110              0.171657
# min              3.000000             2.750000              3.000000
# 25%              3.500000             3.620000              3.620000
# 50%              3.750000             3.750000              3.620000
# 75%              3.880000             3.880000              3.630000
# max              4.120000             4.120000              4.120000
#
#        customer and personal service  mathematics  reading comprehension  \
# count                    4883.000000  4883.000000            4883.000000
# mean                        3.389812     3.225857               3.659934
# std                         0.591357     0.432454               0.289866
# min                         1.330000     1.980000               3.120000
# 25%                         3.010000     2.910000               3.380000
# 50%                         3.640000     3.190000               3.620000
# 75%                         3.710000     3.580000               3.880000
# max                         4.520000     4.910000               4.750000
#
#        active listening  ...  dynamic strength      stamina  \
# count       4883.000000  ...       4883.000000  4883.000000
# mean           3.580766  ...          1.222984     1.065673
# std            0.226561  ...          0.380973     0.242444
# min            2.880000  ...          1.000000     1.000000
# 25%            3.380000  ...          1.000000     1.000000
# 50%            3.500000  ...          1.000000     1.000000
# 75%            3.750000  ...          1.500000     1.000000
# max            4.120000  ...          2.500000     2.880000
#
#        extent flexibility  dynamic flexibility  gross body coordination  \
# count         4883.000000          4883.000000              4883.000000
# mean             1.142412             1.002931                 1.056363
# std              0.322825             0.024617                 0.213988
# min              1.000000             1.000000                 1.000000
# 25%              1.000000             1.000000                 1.000000
# 50%              1.000000             1.000000                 1.000000
# 75%              1.120000             1.000000                 1.000000
# max              3.130000             1.250000                 3.130000
#
#        gross body equilibrium  night vision  peripheral vision  \
# count             4883.000000   4883.000000        4883.000000
# mean                 1.052765      1.023522           1.021577
# std                  0.215003      0.135783           0.144702
# min                  1.000000      1.000000           1.000000
# 25%                  1.000000      1.000000           1.000000
# 50%                  1.000000      1.000000           1.000000
# 75%                  1.000000      1.000000           1.000000
# max                  3.000000      2.500000           2.250000
#
#        glare sensitivity  food production
# count        4883.000000      4883.000000
# mean            1.035259         1.064243
# std             0.164321         0.171011
# min             1.000000         1.000000
# 25%             1.000000         1.000000
# 50%             1.000000         1.040000
# 75%             1.000000         1.060000
# max             2.500000         3.210000
#
# [8 rows x 119 columns]

# %%
# bonus_df[bonus_df['dem_education_level']=='high'].info()

result=bonus_df.groupby(by='dem_education_level').mean()
top_skills_dict={}
for i in result.index:

    top_skills_dict[i]=result.T[i].sort_values(ascending=False)[:10]

    
pd.DataFrame(top_skills_dict).T
# Out:
#         computers and electronics  critical thinking  deductive reasoning  \
# high                     4.298805           3.683588             3.668430
# low                      4.297667           3.685768             3.667957
# medium                   4.313975           3.693933             3.670968
# no                       4.284896           3.666042             3.644687
#
#         english language  information ordering  oral comprehension  \
# high            3.635597              3.652435            3.730037
# low             3.655290              3.658348            3.743565
# medium          3.618211              3.651464            3.740591
# no              3.632083              3.628333            3.740313
#
#         oral expression  problem sensitivity  reading comprehension  \
# high           3.633703             3.747359               3.652728
# low            3.641681             3.741391               3.668913
# medium         3.641757             3.752673               3.664430
# no             3.634896             3.726042               3.669896
#
#         written comprehension
# high                 3.751446
# low                  3.776623
# medium               3.758661
# no                   3.763854

# %% [markdown]
# WEBSCRAPPING

# %%
import requests

url = 'https://ec.europa.eu/eurostat/statistics-explained/index.php/Glossary:Country_codes'
html = requests.get(url).content


from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'html.parser')

table = soup.find('table')

import re
clean_string=re.sub(r'\<.+\>', '', str(table))
clean_string=re.sub(r'\n', '', clean_table)

countries=re.findall(r'[A-Z][a-z]+', clean_string)
# print(countries)

codes=re.findall(r'[A-Z]{2}', clean_string)
# print(codes)
import pandas as pd

# dict={
#     'countries':countries,
#     'codes': codes
# }


# country_codes=pd.DataFrame(dict)

# country_codes

# %%
'abc'.split(' ')
# Out:
# ['abc']

# %%
bonus1['question_bbi_2016wave4_basicincome_argumentsfor']=bonus1.apply(lambda x: x['question_bbi_2016wave4_basicincome_argumentsfor'].split(' | '),axis=1)
bonus1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-c4f8dd21e28d> in <module>
# ----> 1 bonus1['question_bbi_2016wave4_basicincome_argumentsfor']=bonus1.apply(lambda x: x['question_bbi_2016wave4_basicincome_argumentsfor'].split(' | '),axis=1)
#       2 bonus1
#       3
#       4 arguments_pro=[]
#       5 for i in bonus1.index():
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-26-c4f8dd21e28d> in <lambda>(x)
# ----> 1 bonus1['question_bbi_2016wave4_basicincome_argumentsfor']=bonus1.apply(lambda x: x['question_bbi_2016wave4_basicincome_argumentsfor'].split(' | '),axis=1)
#       2 bonus1
#       3
#       4 arguments_pro=[]
#       5 for i in bonus1.index():
#
# AttributeError: 'list' object has no attribute 'split'

# %%
arguments_pro=[]
for i in bonus1.index:
    for j in bonus1.loc[i,'question_bbi_2016wave4_basicincome_argumentsfor']:
        if j not in arguments_pro:
            arguments_pro.append(j)
            
arguments_pro.remove('None of the above')
arguments_pro
# Out:
# ['It increases appreciation for household work and volunteering',
#  'It encourages financial independence and self-responsibility',
#  'It reduces anxiety about financing basic needs',
#  'It creates more equality of opportunity',
#  'It reduces bureaucracy and administrative expenses',
#  'It increases solidarity, because it is funded by everyone']

# %%
def vote(x):
    if x=='I would probably vote for it' or x=='I would vote for it':
        return 'In Favor'
    
    elif x=='I would not vote':
        return 'Neutral'
    
    elif x=='I would probably vote against it' or x=='I would vote against it':
        return  'Against'

# %%
bonus1['Position']=bonus1.apply(lambda x: vote(x['question_bbi_2016wave4_basicincome_vote']),axis=1)
# Out:
# <ipython-input-37-edcb9e14df35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bonus1['simplified_vote']=bonus1.apply(lambda x: vote(x['question_bbi_2016wave4_basicincome_vote']),axis=1)

# %%
def counter(arguments):
    i=0
    for argument in arguments:
        if argument in arguments_pro or argument in arguments_pro :
            i+=1
    return i

# %%
bonus1['Number of Pro arguments']=bonus1.apply(lambda x: counter(x['question_bbi_2016wave4_basicincome_argumentsfor']),axis=1)
bonus1['Number of Cons arguments']=bonus1.apply(lambda x: counter(x['question_bbi_2016wave4_basicincome_argumentsagainst']),axis=1)
# Out:
# <ipython-input-42-dd55fb40defe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bonus1['Number of Pro arguments']=bonus1.apply(lambda x: counter(x['question_bbi_2016wave4_basicincome_argumentsfor']),axis=1)
# <ipython-input-42-dd55fb40defe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bonus1['Number of Cons arguments']=bonus1.apply(lambda x: counter(x['question_bbi_2016wave4_basicincome_argumentsagainst']),axis=1)

# %%
bonus1
# Out:
#      question_bbi_2016wave4_basicincome_vote  \
# 0                           I would not vote
# 1               I would probably vote for it
# 2                           I would not vote
# 3               I would probably vote for it
# 4               I would probably vote for it
# ...                                      ...
# 9644            I would probably vote for it
# 9645        I would probably vote against it
# 9646                        I would not vote
# 9647                     I would vote for it
# 9648                 I would vote against it
#
#         question_bbi_2016wave4_basicincome_argumentsfor  \
# 0                                   [None of the above]
# 1     [It increases appreciation for household work ...
# 2             [It creates more equality of opportunity]
# 3      [It reduces anxiety about financing basic needs]
# 4      [It reduces anxiety about financing basic needs]
# ...                                                 ...
# 9644  [It reduces bureaucracy and administrative exp...
# 9645  [It reduces bureaucracy and administrative exp...
# 9646   [It reduces anxiety about financing basic needs]
# 9647  [It reduces bureaucracy and administrative exp...
# 9648  [It reduces bureaucracy and administrative exp...
#
#      question_bbi_2016wave4_basicincome_argumentsagainst simplified_vote  \
# 0                                     None of the above          Neutral
# 1             It might encourage people to stop working         In Favor
# 2     Foreigners might come to my country and take a...          Neutral
# 3                                     None of the above         In Favor
# 4     It is impossible to finance | It might encoura...         In Favor
# ...                                                 ...              ...
# 9644                        It is impossible to finance         In Favor
# 9645  It might encourage people to stop working | On...          Against
# 9646                                  None of the above          Neutral
# 9647  Foreigners might come to my country and take a...         In Favor
# 9648  It might encourage people to stop working | It...          Against
#
#       Number of Pro arguments  Number of Cons arguments
# 0                           0                         0
# 1                           3                         0
# 2                           1                         0
# 3                           1                         0
# 4                           1                         0
# ...                       ...                       ...
# 9644                        1                         0
# 9645                        1                         0
# 9646                        1                         0
# 9647                        5                         0
# 9648                        1                         0
#
# [9649 rows x 6 columns]

# %%
result=bonus1.groupby(by='simplified_vote').sum()
result
# Out:
#                  Number of Pro arguments  Number of Cons arguments
# simplified_vote
# Against                             2195                         0
# In Favor                           11753                         0
# Neutral                              623                         0

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-09262bd0bafa> in <module>
#       1 {'geography': 4.75, 'written comprehension': 4.25, 'computers and electronics': 4.14, 'reading comprehension': 4.12, 'oral expression': 4.12, 'oral comprehension': 4.0, 'written expression': 4.0, 'active listening': 3.88, 'near vision': 3.88, 'writing': 3.75, 'speaking': 3.75, 'complex problem solving': 3.75, 'english language': 3.68, 'customer and personal service': 3.64, 'critical thinking': 3.62, 'judgment and decision making': 3.62, 'science': 3.62, 'problem sensitivity': 3.62, 'deductive reasoning': 3.62, 'inductive reasoning': 3.62, 'information ordering': 3.62, 'speech clarity': 3.62, 'mathematics': 3.61, 'active learning': 3.5, 'category flexibility': 3.5, 'speech recognition': 3.5, 'systems analysis': 3.38, 'systems evaluation': 3.38, 'selective attention': 3.38, 'engineering and technology': 3.32, 'administration and management': 3.29, 'design': 3.29, 'coordination': 3.25, 'instructing': 3.25, 'time management': 3.25, 'fluency of ideas': 3.25, 'mathematical reasoning': 3.25, 'education and training': 3.25, 'operations analysis': 3.12, 'number facility': 3.12, 'flexibility of closure': 3.12, 'perceptual speed': 3.12, 'visualization': 3.12, 'monitoring': 3.0, 'social perceptiveness': 3.0, 'management of personnel resources': 3.0, 'service orientation': 3.0, 'finger dexterity': 3.0, 'persuasion': 2.88, 'negotiation': 2.88, 'originality': 2.88, 'far vision': 2.88, 'visual color discrimination': 2.88, 'production and processing': 2.82, 'learning strategies': 2.75, 'communications and media': 2.75, 'programming': 2.62, 'law and government': 2.61, 'memorization': 2.5, 'speed of closure': 2.5, 'personnel and human resources': 2.5, 'clerical': 2.46, 'public safety and security': 2.43, 'operation monitoring': 2.38, 'time sharing': 2.38, 'control precision': 2.38, 'sales and marketing': 2.29, 'transportation': 2.29, 'telecommunications': 2.25, 'physics': 2.07, 'economics and accounting': 2.04, 'technology design': 2.0, 'arm-hand steadiness': 2.0, 'manual dexterity': 2.0, 'sociology and anthropology': 2.0, 'biology': 1.96, 'history and archeology': 1.96, 'psychology': 1.89, 'management of financial resources': 1.88, 'management of material resources': 1.88, 'depth perception': 1.75, 'hearing sensitivity': 1.75, 'auditory attention': 1.75, 'mechanical': 1.57, 'chemistry': 1.57, 'fine arts': 1.57, 'building and construction': 1.54, 'philosophy and theology': 1.43, 'equipment selection': 1.38, 'foreign language': 1.36, 'operation and control': 1.25, 'quality control analysis': 1.25, 'multilimb coordination': 1.25, 'medicine and dentistry': 1.18, 'therapy and counseling': 1.18, 'spatial orientation': 1.12, 'trunk strength': 1.12, 'food production': 1.07, 'equipment maintenance': 1.0, 'troubleshooting': 1.0, 'repairing': 1.0, 'installation': 1.0, 'response orientation': 1.0, 'rate control': 1.0, 'reaction time': 1.0, 'wrist-finger speed': 1.0, 'speed of limb movement': 1.0, 'static strength': 1.0, 'explosive strength': 1.0, 'dynamic strength': 1.0, 'stamina': 1.0, 'extent flexibility': 1.0, 'dynamic flexibility': 1.0, 'gross body coordination': 1.0, 'gross body equilibrium': 1.0, 'night vision': 1.0, 'peripheral vision': 1.0, 'glare sensitivity': 1.0, 'sound localization': 1.0}
#       2
# ----> 3 eval(None)
#
# TypeError: eval() arg 1 must be a string, bytes or code object
